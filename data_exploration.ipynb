# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir("/content/drive/MyDrive/smart-cart")

# %% [markdown]
# #Download the dataset

# %%
# !wget https://assets.supervisely.com/supervisely-supervisely-assets-public/teams_storage/6/O/RW/i7P4yZ7P2E4m2DuJBjHqxgl0AjZco5gwVzNUlADpFpfWgCHbzZVB94J2BGCNqFfh24xJVGgmmKIJsIdmWNbWIfgl0AzVishMvnpZ2UncKiIVqjA1isd4mV9QnHSh.tar
# Out:
# --2025-03-08 21:45:55--  https://assets.supervisely.com/supervisely-supervisely-assets-public/teams_storage/6/O/RW/i7P4yZ7P2E4m2DuJBjHqxgl0AjZco5gwVzNUlADpFpfWgCHbzZVB94J2BGCNqFfh24xJVGgmmKIJsIdmWNbWIfgl0AzVishMvnpZ2UncKiIVqjA1isd4mV9QnHSh.tar
# Resolving assets.supervisely.com (assets.supervisely.com)... 94.46.171.158
# Connecting to assets.supervisely.com (assets.supervisely.com)|94.46.171.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667002880 (636M) [application/x-tar]
# Saving to: ‘i7P4yZ7P2E4m2DuJBjHqxgl0AjZco5gwVzNUlADpFpfWgCHbzZVB94J2BGCNqFfh24xJVGgmmKIJsIdmWNbWIfgl0AzVishMvnpZ2UncKiIVqjA1isd4mV9QnHSh.tar’
#
# i7P4yZ7P2E4m2DuJBjH 100%[===================>] 636.10M  31.2MB/s    in 23s
#
# 2025-03-08 21:46:19 (27.3 MB/s) - ‘i7P4yZ7P2E4m2DuJBjHqxgl0AjZco5gwVzNUlADpFpfWgCHbzZVB94J2BGCNqFfh24xJVGgmmKIJsIdmWNbWIfgl0AzVishMvnpZ2UncKiIVqjA1isd4mV9QnHSh.tar’ saved [667002880/667002880]

# %%
# !tar -xvf i7P4yZ7P2E4m2DuJBjHqxgl0AjZco5gwVzNUlADpFpfWgCHbzZVB94J2BGCNqFfh24xJVGgmmKIJsIdmWNbWIfgl0AzVishMvnpZ2UncKiIVqjA1isd4mV9QnHSh.tar -C dataset/
# Out:
# tar: Removing leading `/' from member names
# /
# LICENSE.md
# README.md
# augmented/
# augmented/ann/
# augmented/ann/D2S_99000004_D2S_augmented.jpg.json
# augmented/ann/D2S_99000019_D2S_augmented.jpg.json
# augmented/ann/D2S_99000052_D2S_augmented.jpg.json
# augmented/ann/D2S_99000075_D2S_augmented.jpg.json
# augmented/ann/D2S_99000117_D2S_augmented.jpg.json
# augmented/ann/D2S_99000185_D2S_augmented.jpg.json
# augmented/ann/D2S_99000192_D2S_augmented.jpg.json
# augmented/ann/D2S_99000219_D2S_augmented.jpg.json
# augmented/ann/D2S_99000241_D2S_augmented.jpg.json
# augmented/ann/D2S_99000296_D2S_augmented.jpg.json
# augmented/ann/D2S_99000306_D2S_augmented.jpg.json
# augmented/ann/D2S_99000377_D2S_augmented.jpg.json
# augmented/ann/D2S_99000385_D2S_augmented.jpg.json
# augmented/ann/D2S_99000393_D2S_augmented.jpg.json
# augmented/ann/D2S_99000409_D2S_augmented.jpg.json
# augmented/ann/D2S_99000437_D2S_augmented.jpg.json
# augmented/ann/D2S_99000448_D2S_augmented.jpg.json
# validation/ann/D2S_064117_D2S_validation.jpg.json
# validation/ann/D2S_064125_D2S_validation_random_background.jpg.json
# validation/ann/D2S_064129_D2S_validation.jpg.json
# validation/ann/D2S_064819_D2S_validation.jpg.json
# validation/ann/D2S_065201_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_065207_D2S_validation.jpg.json
# validation/ann/D2S_065222_D2S_validation_random_background.jpg.json
# validation/ann/D2S_065228_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_065300_D2S_validation_random_background.jpg.json
# validation/ann/D2S_065311_D2S_validation.jpg.json
# validation/ann/D2S_065312_D2S_validation_random_background.jpg.json
# validation/ann/D2S_065320_D2S_validation_random_background.jpg.json
# validation/ann/D2S_065327_D2S_validation.jpg.json
# validation/ann/D2S_066209_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066213_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066606_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066610_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066614_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066619_D2S_validation.jpg.json
# validation/ann/D2S_066623_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066625_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066700_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066702_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066709_D2S_validation.jpg.json
# validation/ann/D2S_066712_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066712_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066719_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066724_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066729_D2S_validation_clutter.jpg.json
# validation/ann/D2S_066810_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066811_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_066813_D2S_validation_random_background.jpg.json
# validation/ann/D2S_066816_D2S_validation.jpg.json
# validation/ann/D2S_066818_D2S_validation.jpg.json
# validation/ann/D2S_066829_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_067000_D2S_validation_random_background.jpg.json
# validation/ann/D2S_067008_D2S_validation.jpg.json
# validation/ann/D2S_067011_D2S_validation.jpg.json
# validation/ann/D2S_067024_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_068005_D2S_validation.jpg.json
# validation/ann/D2S_068025_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_068026_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_068028_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068123_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068128_D2S_validation.jpg.json
# validation/ann/D2S_068200_D2S_validation_clutter.jpg.json
# validation/ann/D2S_068204_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068205_D2S_validation_clutter.jpg.json
# validation/ann/D2S_068207_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068209_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068213_D2S_validation.jpg.json
# validation/ann/D2S_068224_D2S_validation.jpg.json
# validation/ann/D2S_068224_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068320_D2S_validation.jpg.json
# validation/ann/D2S_068324_D2S_validation_clutter.jpg.json
# validation/ann/D2S_068328_D2S_validation.jpg.json
# validation/ann/D2S_068401_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068401_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_068414_D2S_validation.jpg.json
# validation/ann/D2S_068415_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068416_D2S_validation.jpg.json
# validation/ann/D2S_068416_D2S_validation_random_background_wo_clutter.jpg.json
# validation/ann/D2S_068420_D2S_validation_random_background.jpg.json
# validation/ann/D2S_068423_D2S_validation_random_background.jpg.json
# validation/ann/D2S_069702_D2S_validation.jpg.json
# validation/ann/D2S_069712_D2S_validation.jpg.json
# validation/ann/D2S_069719_D2S_validation_random_background.jpg.json
# validation/ann/D2S_070007_D2S_validation_random_background.jpg.json
# validation/ann/D2S_070009_D2S_validation_clutter.jpg.json
# validation/ann/D2S_070010_D2S_validation.jpg.json
# validation/ann/D2S_070012_D2S_validation.jpg.json
# validation/ann/D2S_070014_D2S_validation.jpg.json
# validation/ann/D2S_070027_D2S_validation_random_background.jpg.json
# validation/img/
# validation/img/D2S_001900_D2S_validation.jpg
# validation/img/D2S_002721_D2S_validation.jpg
# validation/img/D2S_008927_D2S_validation.jpg
# validation/img/D2S_023001_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_023305_D2S_validation.jpg
# validation/img/D2S_023326_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_023329_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_024200_D2S_validation.jpg
# validation/img/D2S_024206_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_025210_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_025309_D2S_validation.jpg
# validation/img/D2S_025309_D2S_validation_occlusion.jpg
# validation/img/D2S_025709_D2S_validation_occlusion.jpg
# validation/img/D2S_025729_D2S_validation_occlusion.jpg
# validation/img/D2S_025813_D2S_validation_occlusion.jpg
# validation/img/D2S_025911_D2S_validation_occlusion.jpg
# validation/img/D2S_025916_D2S_validation_occlusion.jpg
# validation/img/D2S_026005_D2S_validation.jpg
# validation/img/D2S_027008_D2S_validation_occlusion.jpg
# validation/img/D2S_027010_D2S_validation.jpg
# validation/img/D2S_027011_D2S_validation.jpg
# validation/img/D2S_027015_D2S_validation_occlusion.jpg
# validation/img/D2S_027225_D2S_validation.jpg
# validation/img/D2S_027705_D2S_validation_occlusion.jpg
# validation/img/D2S_027709_D2S_validation_occlusion.jpg
# validation/img/D2S_027718_D2S_validation.jpg
# validation/img/D2S_027727_D2S_validation_occlusion.jpg
# validation/img/D2S_027910_D2S_validation.jpg
# validation/img/D2S_028009_D2S_validation.jpg
# validation/img/D2S_028012_D2S_validation.jpg
# validation/img/D2S_028106_D2S_validation_occlusion.jpg
# validation/img/D2S_028112_D2S_validation.jpg
# validation/img/D2S_028116_D2S_validation.jpg
# validation/img/D2S_028118_D2S_validation.jpg
# validation/img/D2S_028603_D2S_validation_occlusion.jpg
# validation/img/D2S_028617_D2S_validation.jpg
# validation/img/D2S_028806_D2S_validation_occlusion.jpg
# validation/img/D2S_028809_D2S_validation_occlusion.jpg
# validation/img/D2S_028812_D2S_validation.jpg
# validation/img/D2S_028824_D2S_validation.jpg
# validation/img/D2S_030000_D2S_validation.jpg
# validation/img/D2S_030010_D2S_validation.jpg
# validation/img/D2S_030026_D2S_validation_occlusion.jpg
# validation/img/D2S_030202_D2S_validation.jpg
# validation/img/D2S_030907_D2S_validation.jpg
# validation/img/D2S_032712_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_033501_D2S_validation.jpg
# validation/img/D2S_035407_D2S_validation.jpg
# validation/img/D2S_035414_D2S_validation.jpg
# validation/img/D2S_035428_D2S_validation.jpg
# validation/img/D2S_037411_D2S_validation.jpg
# validation/img/D2S_039708_D2S_validation_occlusion.jpg
# validation/img/D2S_039822_D2S_validation_occlusion.jpg
# validation/img/D2S_041413_D2S_validation.jpg
# validation/img/D2S_043205_D2S_validation.jpg
# validation/img/D2S_043217_D2S_validation_occlusion.jpg
# validation/img/D2S_043228_D2S_validation.jpg
# validation/img/D2S_043717_D2S_validation.jpg
# validation/img/D2S_043728_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_044020_D2S_validation_wo_occlusion.jpg
# validation/img/D2S_044315_D2S_validation.jpg
# validation/img/D2S_044703_D2S_validation.jpg
# validation/img/D2S_045120_D2S_validation.jpg
# validation/img/D2S_047704_D2S_validation.jpg
# validation/img/D2S_048606_D2S_validation.jpg
# validation/img/D2S_048627_D2S_validation_occlusion.jpg
# validation/img/D2S_049301_D2S_validation.jpg
# validation/img/D2S_050110_D2S_validation_occlusion.jpg
# validation/img/D2S_050816_D2S_validation_random_background.jpg
# validation/img/D2S_054118_D2S_validation_clutter.jpg
# validation/img/D2S_055220_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_055916_D2S_validation.jpg
# validation/img/D2S_055927_D2S_validation_random_background.jpg
# validation/img/D2S_056007_D2S_validation_random_background.jpg
# validation/img/D2S_056011_D2S_validation.jpg
# validation/img/D2S_056911_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_057805_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_057820_D2S_validation_random_background.jpg
# validation/img/D2S_058612_D2S_validation.jpg
# validation/img/D2S_058623_D2S_validation_random_background.jpg
# validation/img/D2S_058719_D2S_validation_random_background.jpg
# validation/img/D2S_058726_D2S_validation_random_background.jpg
# validation/img/D2S_058729_D2S_validation_clutter.jpg
# validation/img/D2S_060111_D2S_validation_random_background.jpg
# validation/img/D2S_060124_D2S_validation.jpg
# validation/img/D2S_062709_D2S_validation_random_background.jpg
# validation/img/D2S_063405_D2S_validation_random_background.jpg
# validation/img/D2S_063417_D2S_validation_random_background.jpg
# validation/img/D2S_063425_D2S_validation_clutter.jpg
# validation/img/D2S_064109_D2S_validation_random_background.jpg
# validation/img/D2S_064117_D2S_validation.jpg
# validation/img/D2S_064125_D2S_validation_random_background.jpg
# validation/img/D2S_064129_D2S_validation.jpg
# validation/img/D2S_064819_D2S_validation.jpg
# validation/img/D2S_065201_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_065207_D2S_validation.jpg
# validation/img/D2S_065222_D2S_validation_random_background.jpg
# validation/img/D2S_065228_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_065300_D2S_validation_random_background.jpg
# validation/img/D2S_065311_D2S_validation.jpg
# validation/img/D2S_065312_D2S_validation_random_background.jpg
# validation/img/D2S_065320_D2S_validation_random_background.jpg
# validation/img/D2S_065327_D2S_validation.jpg
# validation/img/D2S_066209_D2S_validation_random_background.jpg
# validation/img/D2S_066213_D2S_validation_random_background.jpg
# validation/img/D2S_066606_D2S_validation_clutter.jpg
# validation/img/D2S_066610_D2S_validation_clutter.jpg
# validation/img/D2S_066614_D2S_validation_clutter.jpg
# validation/img/D2S_066619_D2S_validation.jpg
# validation/img/D2S_066623_D2S_validation_random_background.jpg
# validation/img/D2S_066625_D2S_validation_clutter.jpg
# validation/img/D2S_066700_D2S_validation_clutter.jpg
# validation/img/D2S_066702_D2S_validation_random_background.jpg
# validation/img/D2S_066709_D2S_validation.jpg
# validation/img/D2S_066712_D2S_validation_clutter.jpg
# validation/img/D2S_066712_D2S_validation_random_background.jpg
# validation/img/D2S_066719_D2S_validation_random_background.jpg
# validation/img/D2S_066724_D2S_validation_clutter.jpg
# validation/img/D2S_066729_D2S_validation_clutter.jpg
# validation/img/D2S_066810_D2S_validation_random_background.jpg
# validation/img/D2S_066811_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_066813_D2S_validation_random_background.jpg
# validation/img/D2S_066816_D2S_validation.jpg
# validation/img/D2S_066818_D2S_validation.jpg
# validation/img/D2S_066829_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_067000_D2S_validation_random_background.jpg
# validation/img/D2S_067008_D2S_validation.jpg
# validation/img/D2S_067011_D2S_validation.jpg
# validation/img/D2S_067024_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_068005_D2S_validation.jpg
# validation/img/D2S_068025_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_068026_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_068028_D2S_validation_random_background.jpg
# validation/img/D2S_068123_D2S_validation_random_background.jpg
# validation/img/D2S_068128_D2S_validation.jpg
# validation/img/D2S_068200_D2S_validation_clutter.jpg
# validation/img/D2S_068204_D2S_validation_random_background.jpg
# validation/img/D2S_068205_D2S_validation_clutter.jpg
# validation/img/D2S_068207_D2S_validation_random_background.jpg
# validation/img/D2S_068209_D2S_validation_random_background.jpg
# validation/img/D2S_068213_D2S_validation.jpg
# validation/img/D2S_068224_D2S_validation.jpg
# validation/img/D2S_068224_D2S_validation_random_background.jpg
# validation/img/D2S_068320_D2S_validation.jpg
# validation/img/D2S_068324_D2S_validation_clutter.jpg
# validation/img/D2S_068328_D2S_validation.jpg
# validation/img/D2S_068401_D2S_validation_random_background.jpg
# validation/img/D2S_068401_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_068414_D2S_validation.jpg
# validation/img/D2S_068415_D2S_validation_random_background.jpg
# validation/img/D2S_068416_D2S_validation.jpg
# validation/img/D2S_068416_D2S_validation_random_background_wo_clutter.jpg
# validation/img/D2S_068420_D2S_validation_random_background.jpg
# validation/img/D2S_068423_D2S_validation_random_background.jpg
# validation/img/D2S_069702_D2S_validation.jpg
# validation/img/D2S_069712_D2S_validation.jpg
# validation/img/D2S_069719_D2S_validation_random_background.jpg
# validation/img/D2S_070007_D2S_validation_random_background.jpg
# validation/img/D2S_070009_D2S_validation_clutter.jpg
# validation/img/D2S_070010_D2S_validation.jpg
# validation/img/D2S_070012_D2S_validation.jpg
# validation/img/D2S_070014_D2S_validation.jpg
# validation/img/D2S_070027_D2S_validation_random_background.jpg

# %%
# !ls ./dataset/
# Out:
# augmented  LICENSE.md  meta.json  README.md  test  training  validation

# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Instance Categories

# %%
import json

# %%
metadata_path = "./dataset/meta.json"

with open(metadata_path, "r") as f:
  metadata = json.load(f)
metadata.keys()
# Out:
# dict_keys(['classes', 'tags', 'projectType'])

# %%
print("Number of object categories",len(metadata["classes"]))
print("Attributes of a class",metadata["classes"][0].keys())
# Out:
# Number of object categories 60
# Attributes of a class dict_keys(['title', 'shape', 'color', 'geometry_config', 'id', 'hotkey'])

# %%
print("List of object categories:\n",*list(map(lambda instance: instance["title"],metadata["classes"])),sep="\n")
# Out:
# List of object categories:
#
# adelholzener_alpenquelle_classic_075
# adelholzener_alpenquelle_naturell_075
# adelholzener_classic_bio_apfelschorle_02
# adelholzener_classic_naturell_02
# adelholzener_gourmet_mineralwasser_02
# apple_braeburn_bundle
# apple_golden_delicious
# apple_granny_smith
# apple_red_boskoop
# augustiner_lagerbraeu_hell_05
# augustiner_weissbier_05
# avocado
# banana_bundle
# banana_single
# cafe_wunderbar_espresso
# caona_cocoa
# carrot
# clementine
# clementine_single
# coca_cola_05
# coca_cola_light_05
# cocoba_cocoa
# corn_salad
# corny_nussvoll
# corny_nussvoll_single
# corny_schoko_banane
# corny_schoko_banane_single
# cucumber
# douwe_egberts_professional_ground_coffee
# dr_oetker_vitalis_knuspermuesli_klassisch
# ethiquable_gruener_tee_ceylon
# franken_tafelreiniger
# gepa_bio_caffe_crema
# gepa_bio_und_fair_fencheltee
# gepa_bio_und_fair_kamillentee
# gepa_bio_und_fair_kraeuterteemischung
# gepa_bio_und_fair_pfefferminztee
# gepa_bio_und_fair_rooibostee
# gepa_italienischer_bio_espresso
# grapes_green_sugraone_seedless
# grapes_sweet_celebration_seedless
# kilimanjaro_tea_earl_grey
# kiwi
# koelln_muesli_fruechte
# koelln_muesli_schoko
# lettuce
# oranges
# orange_single
# pasta_reggia_elicoidali
# pasta_reggia_fusilli
# pasta_reggia_spaghetti
# pear
# pelikan_tintenpatrone_canon
# rocket
# roma_vine_tomatoes
# salad_iceberg
# suntory_gokuri_lemonade
# tegernseer_hell_03
# vine_tomatoes
# zucchini

# %%
# Check whether all images have the same size
# accross all sets
train_path = "./dataset/training/ann"
val_path = "./dataset/validation/ann"
test_path = "./dataset/test/ann"
aug_path = "./dataset/augmented/ann"

# %% [markdown]
# ## Class Sizes

# %%
def check_image_size_variability(shapes):
  return all([shape == shapes[0] for shape in shapes[1:]])

def get_shapes(ann_path):
  shapes = []
  for root, subdirs, filenames in os.walk(ann_path):

    for filename in filenames:

      abs_path = os.path.join(root, filename)

      with open(abs_path, "r") as f:
        metadata = json.load(f)

      shapes.append((metadata['size']['height'],
                     metadata['size']['width']
                     ))
  return shapes

# %%
train_shapes = get_shapes(train_path)
aug_shapes = get_shapes(aug_path)
val_shapes = get_shapes(val_path)
test_shapes = get_shapes(test_path)

# %%
check_image_size_variability(train_shapes),check_image_size_variability(aug_shapes),check_image_size_variability(val_shapes),check_image_size_variability(test_shapes)
# Out:
# (True, True, True, True)

# %%
dataset_shapes = [*train_shapes,*aug_shapes,*val_shapes,*test_shapes]
check_image_size_variability(dataset_shapes)
# Out:
# True

# %%
train_shapes[0]
# Out:
# (1440, 1920)

# %% [markdown]
# All images in the dataset have the same shape of 1920*1440

# %%
print(f"Total images used in training: {len(train_shapes)+len(aug_shapes)}")
print(f"Total images used in validation: {len(val_shapes)}")
print(f"Total images used in testing: {len(test_shapes)}")
# Out:
# Total images used in training: 420
# Total images used in validation: 163
# Total images used in testing: 445

# %% [markdown]
# ## Class Balance

# %%
# Verify that each class is present in the training
class_ids = list(map(lambda x: x["id"],metadata["classes"]))
class_ids[-1]
# Out:
# 28369

# %%
# Get classes present in each set
def get_all_instances_values_by_key(key, ann):

  values = []

  for obj in ann["objects"]:
    value = obj[key]
    assert not isinstance(value,list) , f"This method doesn't support values of type list"

    values.append(value)

  return values

# %%
train_class_ids = []
for annotatio_path in os.listdir(train_path):

  abs_path = os.path.join(train_path, annotatio_path)

  with open(abs_path, "r") as f:
    image_meta = json.load(f)

  train_class_ids.extend(get_all_instances_values_by_key("classId", image_meta))

train_class_ids = set(train_class_ids)

len(train_class_ids) == len(metadata["classes"]), len(train_class_ids) , len(metadata["classes"])
# Out:
# (False, 34, 60)

# %%
val_class_ids = []
for annotatio_path in os.listdir(val_path):

  abs_path = os.path.join(val_path, annotatio_path)

  with open(abs_path, "r") as f:
    image_meta = json.load(f)

  val_class_ids.extend(get_all_instances_values_by_key("classId", image_meta))

val_class_ids = set(val_class_ids)

len(val_class_ids) == len(metadata["classes"]), len(val_class_ids) , len(metadata["classes"])
# Out:
# (True, 60, 60)

# %%
aug_class_ids = []
for annotatio_path in os.listdir(aug_path):

  abs_path = os.path.join(aug_path, annotatio_path)

  with open(abs_path, "r") as f:
    image_meta = json.load(f)

  aug_class_ids.extend(get_all_instances_values_by_key("classId", image_meta))

aug_class_ids = set(aug_class_ids)

len(aug_class_ids) == len(metadata["classes"]), len(aug_class_ids) , len(metadata["classes"])
# Out:
# (True, 60, 60)

# %%
test_class_ids = []
for annotatio_path in os.listdir(test_path):

  abs_path = os.path.join(test_path, annotatio_path)

  with open(abs_path, "r") as f:
    image_meta = json.load(f)

  test_class_ids.extend(get_all_instances_values_by_key("classId", image_meta))

test_class_ids = set(test_class_ids)

len(test_class_ids) == len(metadata["classes"]), len(test_class_ids) , len(metadata["classes"])
# Out:
# (False, 0, 60)

# %%
train_class_ids == val_class_ids , train_class_ids == aug_class_ids, train_class_ids ==test_class_ids
# Out:
# (False, False, False)

# %%
aug_class_ids.intersection(train_class_ids) == train_class_ids
# Out:
# True

# %%
metadata_path = "./dataset/meta.json"

with open(metadata_path, "r") as f:
  metadata = json.load(f)

orig_class_ids = list(map(lambda meta: meta["id"], metadata["classes"]))
classId_idx = {class_meta["id"]: idx for idx, class_meta in enumerate(metadata["classes"])}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.patches import Polygon
import numpy as np

def read_annotation(ann_path):

  with open(ann_path, "r") as f:
    annotation = json.load(f)

  return annotation

def get_instance_count_per_class(src):

  class_count = defaultdict(int)

  for root, _, filenames in os.walk(src):
    for filename in filenames:

      ann = read_annotation(os.path.join(root, filename))

      for obj in ann["objects"]:
        id = classId_idx[obj["classId"]]
        class_count[id] += 1
  return class_count

def polygon_area(polygon):

    # compute polygon area using showlace formula
    verts = polygon.get_xy()  # Get polygon vertices (including closing point)
    x, y = verts[:, 0], verts[:, 1]

    return 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))

def get_avg_instance_area_per_class(src):

  class_area = defaultdict(list)

  for root, _, filenames in os.walk(src):
    for filename in filenames:

      ann = read_annotation(os.path.join(root, filename))

      for obj in ann["objects"]:
        points = obj["points"]["exterior"]
        polygon = Polygon([*points])
        class_id = classId_idx[obj["classId"]]

        image_area = ann["size"]["height"]*ann["size"]["width"]
        area = polygon_area(polygon)
        area_per_pixel = area/image_area
        class_area[class_id].append(area_per_pixel)

  class_area = {k:np.mean(v) for k,v in class_area.items()}

  return class_area




def plot_histogram(data, title):

  plt.figure(figsize=(15,6))
  x,y = data
  sns.barplot(x=x, y=y, palette="viridis")
  plt.title(title)
  plt.show()

# %%
train_path = "./dataset/training/ann"
val_path = "./dataset/validation/ann"
test_path = "./dataset/test/ann"
aug_path = "./dataset/augmented/ann"

instance_count_per_class = get_instance_count_per_class(train_path)
avg_instance_area_per_class = get_avg_instance_area_per_class(train_path)
plot_histogram((instance_count_per_class.keys(), instance_count_per_class.values()), "Instances per class in Original Train Set")
# Out:
# <ipython-input-41-61224dff7284>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
plot_histogram((instance_count_per_class.keys(), avg_instance_area_per_class.values()), "Avg Area per class in Original Train Set")
# Out:
# <ipython-input-41-61224dff7284>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
instance_count_per_class = get_instance_count_per_class(aug_path)
avg_instance_area_per_class = get_avg_instance_area_per_class(aug_path)
plot_histogram((instance_count_per_class.keys(), instance_count_per_class.values()), "Instances per class in Original Augmented Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
plot_histogram((instance_count_per_class.keys(), avg_instance_area_per_class.values()), "Avg Area per class in Original Augmented Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
# merge Training + Augmented Sets
def merge_dicts_add_values(dict1, dict2, add_values=True):
    merged = defaultdict(int)  # Default value is 0 for missing keys
    for d in (dict1, dict2):  # Loop through both dictionaries
        for key, value in d.items():
            if add_values:
                merged[key] += value  # Add values if key exists, otherwise assign
            else:
              merged[key] = value
    return dict(merged)

# %%
tr_instance_count_per_class = get_instance_count_per_class(train_path)
tr_avg_instance_area_per_class = get_avg_instance_area_per_class(train_path)

aug_instance_count_per_class = get_instance_count_per_class(aug_path)
aug_avg_instance_area_per_class = get_avg_instance_area_per_class(aug_path)

merged_train_aug_instance_count_per_class = merge_dicts_add_values(tr_instance_count_per_class, aug_instance_count_per_class)
merged_train_aug_avg_instance_area_per_class = merge_dicts_add_values(tr_avg_instance_area_per_class, aug_avg_instance_area_per_class, add_values=False)

# %%
plot_histogram((merged_train_aug_instance_count_per_class.keys(), merged_train_aug_instance_count_per_class.values()), "Instances per class in New Training Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
plot_histogram((merged_train_aug_avg_instance_area_per_class.keys(), merged_train_aug_avg_instance_area_per_class.values()), "Avg Area per class in New Training Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
instance_count_per_class = get_instance_count_per_class(val_path)
avg_instance_area_per_class = get_avg_instance_area_per_class(val_path)
plot_histogram((instance_count_per_class.keys(), instance_count_per_class.values()), "Instances per class in Original Validation Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %%
plot_histogram((instance_count_per_class.keys(), avg_instance_area_per_class.values()), "Avg Area per class in Original Validation Set")
# Out:
# <ipython-input-45-6c17ed8da948>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette="viridis")

# %% [markdown]
# We notice that the instances in the validation set, has a little bit higher ares compared to the images in the training set. Which may cause some errors in segmentation during inference

# %% [markdown]
# ## Plotting Sample images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

def get_class_color_dict(gloabal_metadata):

  classId_color = {}

  for class_ in gloabal_metadata["classes"]:
    classId_color[class_["id"]] = class_["color"]

  return classId_color

classId_colors = get_class_color_dict(metadata)

def hex_2_rgb(hex_color):

  hex = hex_color.lstrip("#")
  rgb = tuple(int(hex[i:i+2], 16) for i in (0, 2, 4))

  return rgb


def plot_image_instance_mask(image_path, ann_path):

  image = cv2.imread(image_path)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

  with open(ann_path, "r") as f:
    ann = json.load(f)

  fig, ax = plt.subplots(1,1)

  for instance in ann["objects"]:

    hex_color = classId_colors[instance["classId"]]
    # print(h_color)
    points = instance["points"]["exterior"]
    polygon = Polygon([*points], color=hex_color, alpha=0.9)

    ax.add_patch(polygon)


  ax.imshow(image, alpha=0.8)
  plt.show()

# %%
image_path = "./dataset/training/img/D2S_001218_D2S_training.jpg"
ann_path = "./dataset/training/ann/D2S_001218_D2S_training.jpg.json"
plot_image_instance_mask(image_path, ann_path)

# %%
1920/3, 1440/3
# Out:
# (640.0, 480.0)
